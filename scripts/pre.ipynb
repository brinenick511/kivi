# %%
base=f'32_0_32_16_new'
s=f''
for i in range(3):
    for j in range(3):
        if j == 0:
            continue
        ss=f'{base}_{i}_{j}'
        s=f'{s}{ss} '
s=f'anno_list=({s})'
print(s)
# Out:
# anno_list=(32_0_32_16_new_0_1 32_0_32_16_new_0_2 32_0_32_16_new_1_1 32_0_32_16_new_1_2 32_0_32_16_new_2_1 32_0_32_16_new_2_2 )
